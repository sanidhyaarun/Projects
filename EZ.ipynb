# %%
import pandas as pd
import numpy as np
import seaborn as sb

# %%
titanic=sb.load_dataset("titanic")
titanic.shape
# Out:
# (891, 15)

# %%
df1=titanic.sample(n=100, random_state=0)
df1.shape
# Out:
# (100, 15)

# %%
df2=titanic.sample(n=100, random_state=1)
df2.shape
# Out:
# (100, 15)

# %%
df1.head()
# Out:
#      survived  pclass     sex   age  sibsp  parch      fare embarked  class  \
# 495         0       3    male   NaN      0      0   14.4583        C  Third
# 648         0       3    male   NaN      0      0    7.5500        S  Third
# 278         0       3    male   7.0      4      1   29.1250        Q  Third
# 31          1       1  female   NaN      1      0  146.5208        C  First
# 255         1       3  female  29.0      0      2   15.2458        C  Third
#
#        who  adult_male deck  embark_town alive  alone
# 495    man        True  NaN    Cherbourg    no   True
# 648    man        True  NaN  Southampton    no   True
# 278  child       False  NaN   Queenstown    no  False
# 31   woman       False    B    Cherbourg   yes  False
# 255  woman       False  NaN    Cherbourg   yes  False

# %%
df2.head()
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 862         1       1  female  48.0      0      0  25.9292        S   First
# 223         0       3    male   NaN      0      0   7.8958        S   Third
# 84          1       2  female  17.0      0      0  10.5000        S  Second
# 680         0       3  female   NaN      0      0   8.1375        Q   Third
# 535         1       2  female   7.0      0      2  26.2500        S  Second
#
#        who  adult_male deck  embark_town alive  alone
# 862  woman       False    D  Southampton   yes   True
# 223    man        True  NaN  Southampton    no   True
# 84   woman       False  NaN  Southampton   yes   True
# 680  woman       False  NaN   Queenstown    no   True
# 535  child       False  NaN  Southampton   yes  False

# %%
df1["carrier_premium"] = np.random.randint(500,50000,size=100)
df1["zipcode"] = np.random.randint(123456,123465,size=100)

# %%
df1.shape
# Out:
# (100, 17)

# %%
df2["count"] = np.random.randint(1,5,size=100)
df2["premium_min"] = np.random.randint(500,50000,size=100)
df2["premium_max"] = np.random.randint(500,50000,size=100)
df2["premium_median"] = np.random.randint(500,50000,size=100)

# %%
df2.shape
# Out:
# (100, 19)

# %%
df2["count"].count()
# Out:
# 100

# %%
columns1 = df1.columns
print("columns1 :" , columns1)
columns11 = columns1[:15]
print("columns11 :" ,columns11)
# Out:
# columns1 : Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone', 'carrier_premium', 'zipcode'],
#       dtype='object')
# columns11 : Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')

# %%
columns2 = df2.columns
print("columns2 :" , columns2)
columns22 = columns2[:15]
print("columns22 :" ,columns22)
# Out:
# columns2 : Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone', 'count', 'premium_min', 'premium_max',
#        'premium_median'],
#       dtype='object')
# columns22 : Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')

# %%
df1[columns1]
# Out:
#      survived  pclass     sex    age  sibsp  parch      fare embarked   class  \
# 495         0       3    male    NaN      0      0   14.4583        C   Third
# 648         0       3    male    NaN      0      0    7.5500        S   Third
# 278         0       3    male   7.00      4      1   29.1250        Q   Third
# 31          1       1  female    NaN      1      0  146.5208        C   First
# 255         1       3  female  29.00      0      2   15.2458        C   Third
# 298         1       1    male    NaN      0      0   30.5000        S   First
# 609         1       1  female  40.00      0      0  153.4625        S   First
# 318         1       1  female  31.00      0      2  164.8667        S   First
# 484         1       1    male  25.00      1      0   91.0792        C   First
# 367         1       3  female    NaN      0      0    7.2292        C   Third
# 704         0       3    male  26.00      1      0    7.8542        S   Third
# ...

# %%
# for index1, row1 in df1[columns11].head(1).iterrows():
#     for index2, row2 in df2[columns22].head(1).iterrows():
#         a=[]
#         b=[]
#         a.append(row1.values)
#         b.append(row2.values)
#         print(a)
#         print(b)
# #         print(row2.values)
#         if a==b:
#             print("Hi")
#         else:
#             print("NO")

# %%
def dataframe_difference(df1,df2, which=None):
    """Find rows which are different between two DataFrames."""
    comparison_df = df1.merge(
        df2,
        indicator=True,
        how='outer'
    )
    if which is None:
        diff_df = comparison_df[comparison_df['_merge'] != 'both']
    else:
        diff_df = comparison_df[comparison_df['_merge'] == which]
    diff_df.to_csv('diff.csv')
#     df3=pd.DataFrame(diff_df)
    return diff_df

# %%
dataframe_difference(df1, df2, which='both')
# Out:
#      survived  pclass     sex   age  sibsp  parch      fare embarked   class  \
# 4           1       3  female  29.0      0      2   15.2458        C   Third
# 5           1       1    male   NaN      0      0   30.5000        S   First
# 12          0       3    male   NaN      0      0    7.7500        Q   Third
# 13          1       2  female   7.0      0      2   26.2500        S  Second
# 21          1       1  female  22.0      0      0  151.5500        S   First
# 43          0       3    male  14.0      4      1   39.6875        S   Third
# 45          0       3    male   NaN      0      0    7.8958        S   Third
# 46          0       3    male   NaN      0      0    7.8958        S   Third
# 47          0       3    male   NaN      0      0    7.8958        S   Third
# 48          0       3    male   NaN      0      0    7.8958        S   Third
# 49          0       3    male   NaN      0      0    7.8958        S   Third
# ...

# %%
df3=pd.read_csv("diff.csv")
df3.head()
# Out:
#    zipcode  survived  pclass     sex   age  sibsp  parch     fare embarked  \
# 0   123457         1       3  female  29.0      0      2  15.2458        C
# 1   123459         1       1    male   NaN      0      0  30.5000        S
# 2   123458         0       3    male   NaN      0      0   7.7500        Q
# 3   123457         1       3  female  29.0      0      2  15.2458        C
# 4   123460         1       2  female   7.0      0      2  26.2500        S
#
#     class   ...   deck  embark_town alive  alone carrier_premium  count  \
# 0   Third   ...    NaN    Cherbourg   yes  False           25305      4
# 1   First   ...      C  Southampton   yes   True           42806      1
# 2   Third   ...    NaN   Queenstown    no   True           20830      1
# 3   Third   ...    NaN    Cherbourg   yes  False           25305      2
# 4  Second   ...    NaN  Southampton   yes  False           19905      3
#
#    premium_min  premium_max  premium_median  _merge
# ...

# %%
df3.shape
# Out:
# (30, 22)

# %%
for index, row in df3.head(2).iterrows():
    print(row)
# Out:
# zipcode               123457
# survived                   1
# pclass                     3
# sex                   female
# age                       29
# sibsp                      0
# parch                      2
# fare                 15.2458
# embarked                   C
# class                  Third
# who                    woman
# adult_male             False
# deck                     NaN
# embark_town        Cherbourg
# alive                    yes
# alone                  False
# carrier_premium        25305
# count                      4
# premium_min            21116
# premium_max            34530
# premium_median          6443
# _merge                  both
# Name: 0, dtype: object
# zipcode                 123459
# survived                     1
# pclass                       1
# sex                       male
# age                        NaN
# sibsp                        0
# parch                        0
# fare                      30.5
# ...

# %%
df4=df3.drop(["count"] , axis=1)

# %%
duplicate = df4[df4.duplicated()] 
duplicate
# Out:
#     zipcode  survived  pclass     sex   age  sibsp  parch     fare embarked  \
# 3    123457         1       3  female  29.0      0      2  15.2458        C
# 8    123459         1       1    male   NaN      0      0  30.5000        S
# 23   123457         0       2    male  28.0      0      1  33.0000        S
# 24   123463         0       3    male  10.0      3      2  27.9000        S
# 29   123458         0       3    male   NaN      0      0   7.2292        C
#
#      class   ...   adult_male  deck  embark_town alive  alone  \
# 3    Third   ...        False   NaN    Cherbourg   yes  False
# 8    First   ...         True     C  Southampton   yes   True
# 23  Second   ...         True   NaN  Southampton    no  False
# 24   Third   ...        False   NaN  Southampton    no  False
# 29   Third   ...         True   NaN    Cherbourg    no   True
#
#     carrier_premium  premium_min  premium_max  premium_median  _merge
# ...

# %%
for row in duplicate.index: 
    print(row, end = " ")
# Out:
# 3 8 23 24 29

# %%
x=[1,2,3]
y=[1,2,3]
z=[]
print(x)
z.append(x)
print(z)
if z==y:
    print("Hi")
else:
    print("NO")
# Out:
# [1, 2, 3]
# [[1, 2, 3]]
# NO
