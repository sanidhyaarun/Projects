# %%
import pandas as pd
import numpy as np
import seaborn as sb

# %%
titanic=sb.load_dataset("titanic")
titanic.shape
# Out:
# (891, 15)

# %%
df1=titanic.sample(n=500, random_state=0)
df1.shape
# Out:
# (500, 15)

# %%
df2=titanic.sample(n=500, random_state=1)
df2.shape
# Out:
# (500, 15)

# %%
df1.head()
# Out:
#      survived  pclass     sex   age  sibsp  parch      fare embarked  class  \
# 495         0       3    male   NaN      0      0   14.4583        C  Third
# 648         0       3    male   NaN      0      0    7.5500        S  Third
# 278         0       3    male   7.0      4      1   29.1250        Q  Third
# 31          1       1  female   NaN      1      0  146.5208        C  First
# 255         1       3  female  29.0      0      2   15.2458        C  Third
#
#        who  adult_male deck  embark_town alive  alone
# 495    man        True  NaN    Cherbourg    no   True
# 648    man        True  NaN  Southampton    no   True
# 278  child       False  NaN   Queenstown    no  False
# 31   woman       False    B    Cherbourg   yes  False
# 255  woman       False  NaN    Cherbourg   yes  False

# %%
df2.head()
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 862         1       1  female  48.0      0      0  25.9292        S   First
# 223         0       3    male   NaN      0      0   7.8958        S   Third
# 84          1       2  female  17.0      0      0  10.5000        S  Second
# 680         0       3  female   NaN      0      0   8.1375        Q   Third
# 535         1       2  female   7.0      0      2  26.2500        S  Second
#
#        who  adult_male deck  embark_town alive  alone
# 862  woman       False    D  Southampton   yes   True
# 223    man        True  NaN  Southampton    no   True
# 84   woman       False  NaN  Southampton   yes   True
# 680  woman       False  NaN   Queenstown    no   True
# 535  child       False  NaN  Southampton   yes  False

# %%
df1["zipcode"] = np.random.randint(123456,123465,size=500)
df1["carrier_premium"] = np.random.randint(500,50000,size=500)

# %%
df1.shape
# Out:
# (500, 17)

# %%
df2["zipcode"] = np.random.randint(123456,123465,size=500)
df2["count"] = np.random.randint(1,5,size=500)
df2["premium_min"] = np.random.randint(500,50000,size=500)
df2["premium_max"] = np.random.randint(500,50000,size=500)
df2["premium_median"] = np.random.randint(500,50000,size=500)

# %%
df2.shape
# Out:
# (500, 20)

# %%
df2["count"].count()
# Out:
# 500

# %%
columns1 = df1.columns
print("columns1 :" , columns1)
columns11 = columns1[:16]
print("columns11 :" ,columns11)
# Out:
# columns1 : Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone', 'zipcode', 'carrier_premium'],
#       dtype='object')
# columns11 : Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone', 'zipcode'],
#       dtype='object')

# %%
df1["merged_1"]=df1[columns11].apply(lambda row: ''.join(row.values.astype(str)), axis=1)
df1.head()
# Out:
#      survived  pclass     sex   age  sibsp  parch      fare embarked  class  \
# 495         0       3    male   NaN      0      0   14.4583        C  Third
# 648         0       3    male   NaN      0      0    7.5500        S  Third
# 278         0       3    male   7.0      4      1   29.1250        Q  Third
# 31          1       1  female   NaN      1      0  146.5208        C  First
# 255         1       3  female  29.0      0      2   15.2458        C  Third
#
#        who  adult_male deck  embark_town alive  alone  zipcode  \
# 495    man        True  NaN    Cherbourg    no   True   123464
# 648    man        True  NaN  Southampton    no   True   123458
# 278  child       False  NaN   Queenstown    no  False   123456
# 31   woman       False    B    Cherbourg   yes  False   123462
# 255  woman       False  NaN    Cherbourg   yes  False   123458
#
#      carrier_premium                                           merged_1
# ...

# %%
columns2 = df2.columns
print("columns2 :" , columns2)
columns22 = columns2[:16]
print("columns22 :" ,columns22)
# Out:
# columns2 : Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone', 'zipcode', 'count', 'premium_min', 'premium_max',
#        'premium_median'],
#       dtype='object')
# columns22 : Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone', 'zipcode'],
#       dtype='object')

# %%
df2["merged_2"]=df2[columns22].apply(lambda row: ''.join(row.values.astype(str)), axis=1)
df2.head()
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 862         1       1  female  48.0      0      0  25.9292        S   First
# 223         0       3    male   NaN      0      0   7.8958        S   Third
# 84          1       2  female  17.0      0      0  10.5000        S  Second
# 680         0       3  female   NaN      0      0   8.1375        Q   Third
# 535         1       2  female   7.0      0      2  26.2500        S  Second
#
#        who  ...  deck  embark_town alive  alone  zipcode  count  premium_min  \
# 862  woman  ...     D  Southampton   yes   True   123457      3        22167
# 223    man  ...   NaN  Southampton    no   True   123457      2         3953
# 84   woman  ...   NaN  Southampton   yes   True   123458      4        34689
# 680  woman  ...   NaN   Queenstown    no   True   123463      2        24130
# 535  child  ...   NaN  Southampton   yes  False   123457      2        26107
#
#      premium_max  premium_median  \
# ...

# %%
# z=[]
# for i in df1["merged_1"]:
#     for j in df2["merged_2"]:
#         if i==j:
#             indxe= df1[df1["merged_1"]==j].index.values
#             print(df1["carrier_premium"][indxe].median())
# #             z.append(df1["carrier_premium"][indxe].sum)
# #             print(len(z))

# %%
df1["median_estimated_premium"]= np.nan
df1["median_carrier_premium"]= np.nan
df1["premium_difference"] = np.nan

# %%
for i in df1["merged_1"]:
    for j in df2["merged_2"]:
        if i==j:
            a=0
            b=[]
                        
            for k in df2[df2["merged_2"]==j].index.values:
                a+=df2["count"][k]
                b.append(df2["premium_median"][k])
                index_1=df1[df1["merged_1"]==j].index.values
                
                if a>=5:
                    print("Common value in df1 and df2 from df2 table] :", j)
                    print("Summation of df2[count] values for common rows :", a)
                    print("Index of rows for common values in df2[merged]: ", df2[df2["merged_2"]==j].index.values)
                    print("Median Premium for common rows in df1 and df2: ", np.median(np.array(b)))
                    df1["median_estimated_premium"][index_1]= np.median(np.array(b))
                    print("Carrier Premium from df1 :", df1["carrier_premium"][index_1])
                    print("Median Carrier Premium :", df1["carrier_premium"][index_1].median())
                    df1["median_carrier_premium"][index_1]=df1["carrier_premium"][index_ 
                    print("Difference in the premium :", df1["carrier_premium"][index_1].median() - (np.median(np.array(b))))
                    df1["premium_difference"][index_1]= df1["carrier_premium"][index_1].median() - (np.median(np.array(b)))
                    print()
# Out:
# Common value in df1 and df2 from df2 table] : 03malenan008.05SThirdmanTruenanSouthamptonnoTrue123463
# Summation of df2[count] values for common rows : 7
# Index of rows for common values in df2[merged]:  [589 121]
# Median Premium for common rows in df1 and df2:  39039.0
# Carrier Premium from df1 : 304    5831
# 563    2712
# Name: carrier_premium, dtype: int32
# Median Carrier Premium : 4271.5
# Difference in the premium : -34767.5
#
# Common value in df1 and df2 from df2 table] : 03malenan008.05SThirdmanTruenanSouthamptonnoTrue123463
# Summation of df2[count] values for common rows : 7
# Index of rows for common values in df2[merged]:  [589 121]
# Median Premium for common rows in df1 and df2:  39039.0
# Carrier Premium from df1 : 304    5831
# 563    2712
# Name: carrier_premium, dtype: int32
# Median Carrier Premium : 4271.5
# Difference in the premium : -34767.5
#
# Common value in df1 and df2 from df2 table] : 03malenan007.8958SThirdmanTruenanSouthamptonnoTrue123457
# ...

# %%
# for i in df1["merged_1"]:
#     for j in df2["merged_2"]:
#         if i==j:
#             a=0
#             b=0
#             c=0
                        
#             for k in df2[df2["merged_2"]==j].index.values:
#                 a+=df2["count"][k]
#                 b+=df2["premium_median"][k]
#                 c+=1
#                 index_1=df1[df1["merged_1"]==j].index.values
                
#                 if a>=5:
#                     print("Common value in df1 and df2 from df2 table] :", j)
#                     print("Summation of df2[count] values for common rows :", a)
#                     print("Index of rows for common values in df2[merged]: ", df2[df2["merged_2"]==j].index.values)
#                     print("Median Premium for common rows in df1 and df2: ", b/c)
#                     df1["median_estimated_premium"][index_1]=b/c
#                     print("Carrier Premium from df1 :", df1["carrier_premium"][index_1])
#                     print("Median Carrier Premium :", df1["carrier_premium"][index_1].median())
#                     df1["median_carrier_premium"][index_1]=df1["carrier_premium"][index_1].median()
#                     print("Difference in the premium :", df1["carrier_premium"][index_1].median() - (b/c))
#                     df1["premium_difference"][index_1]= df1["carrier_premium"][index_1].median() - (b/c)
#                     print()

# %%
df1
# Out:
#      survived  pclass     sex   age  sibsp  parch      fare embarked  class  \
# 495         0       3    male   NaN      0      0   14.4583        C  Third
# 648         0       3    male   NaN      0      0    7.5500        S  Third
# 278         0       3    male   7.0      4      1   29.1250        Q  Third
# 31          1       1  female   NaN      1      0  146.5208        C  First
# 255         1       3  female  29.0      0      2   15.2458        C  Third
# ..        ...     ...     ...   ...    ...    ...       ...      ...    ...
# 687         0       3    male  19.0      0      0   10.1708        S  Third
# 860         0       3    male  41.0      2      0   14.1083        S  Third
# 737         1       1    male  35.0      0      0  512.3292        C  First
# 844         0       3    male  17.0      0      0    8.6625        S  Third
# 454         0       3    male   NaN      0      0    8.0500        S  Third
#
# ...

# %%
df1["median_estimated_premium"].unique()
# Out:
# array([    nan, 39039. , 35569.5])

# %%
df1["median_carrier_premium"].unique()
# Out:
# array([    nan,  4271.5, 35076. ])

# %%
df1["premium_difference"].unique()
# Out:
# array([     nan, -34767.5,   -493.5])

# %%
df1["median_estimated_premium"]
# Out:
# 495   NaN
# 648   NaN
# 278   NaN
# 31    NaN
# 255   NaN
#        ..
# 687   NaN
# 860   NaN
# 737   NaN
# 844   NaN
# 454   NaN
# Name: median_estimated_premium, Length: 500, dtype: float64

# %%
a=0
b=[]
c=0
for k in df2[df2["merged_2"]=="03malenan007.8958SThirdmanTruenanSouthamptonnoTrue123463"].index.values:
    a+=df2["count"][k]
    b.append(df2["premium_median"][k])
    c+=1
    print("count: ", a)
    print("premiums: ", b)
    print("no. of premiums: ", c)
    print("Median Premium: ", np.median(np.array(b)))
    
if a>=5:
    print("Hi")
# Out:
# count:  3
# premiums:  [14175]
# no. of premiums:  1
# Median Premium:  14175.0

# %%
df2["count"][45]
# Out:
# 1

# %%
df2[df2["merged_2"]=="03malenan008.05SThirdmanTruenanSouthamptonnoTrue123464"].index.values.sum()
# Out:
# 0

# %%
for i in df2[df2["merged_2"]=="03malenan008.05SThirdmanTruenanSouthamptonnoTrue123464"].index.values:
    print(i.sum())

# %% [markdown]
# # Completed

# %%
a=0
for k in df2[df2["merged_2"]=="03malenan007.8958SThirdmanTruenanSouthamptonnoTrue123456"].index.values:
    a+=df2["count"][k]
if a>=5:
    print("Hi")
#                 print(df2["count"][k].sum())

# %%
# for index1, row1 in df1[columns11].head(1).iterrows():
#     for index2, row2 in df2[columns22].head(1).iterrows():
#         a=[]
#         b=[]
#         a.append(row1.values)
#         b.append(row2.values)
#         print(a)
#         print(b)
# #         print(row2.values)
#         if a==b:
#             print("Hi")
#         else:
#             print("NO")

# %%
# def dataframe_difference(df1,df2, which=None):
#     """Find rows which are different between two DataFrames."""
#     comparison_df = df1.merge(
#         df2,
#         indicator=True,
#         how='outer'
#     )
#     if which is None:
#         diff_df = comparison_df[comparison_df['_merge'] != 'both']
#     else:
#         diff_df = comparison_df[comparison_df['_merge'] == which]
#     diff_df.to_csv('diff.csv')
# #     df3=pd.DataFrame(diff_df)
#     return diff_df

# %%
# dataframe_difference(df1, df2, which='both')

# %%
# df3=pd.read_csv("diff.csv")
# df3.head()

# %%
# df3.shape

# %%
x=[1,2,3]
y=[1,2,3]
z=[]
print(x)
z.append(x)
print(z)
if z==y:
    print("Hi")
else:
    print("NO")
# Out:
# [1, 2, 3]
# [[1, 2, 3]]
# NO

# %%
jahaj=sb.load_dataset("titanic")
jahaj.shape
# Out:
# (891, 15)

# %%
jahaj.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')

# %%
jahaj.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
jahaj["yuhi"]=np.nan

# %%
jahaj.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone  yuhi
# 0    man        True  NaN  Southampton    no  False   NaN
# 1  woman       False    C    Cherbourg   yes  False   NaN
# 2  woman       False  NaN  Southampton   yes   True   NaN
# 3  woman       False    C  Southampton   yes  False   NaN
# 4    man        True  NaN  Southampton    no   True   NaN

# %%
for i in jahaj["survived"].head():
    for j in jahaj["sibsp"].head():
        if i==j:
            print(jahaj[jahaj["survived"]==0].index.values)
            jahaj["yuhi"][jahaj[jahaj["survived"]==0].index.values]=10
# Out:
# [  0   4   5   6   7  12  13  14  16  18  20  24  26  27  29  30  33  34
#   35  37  38  40  41  42  45  46  48  49  50  51  54  57  59  60  62  63
#   64  67  69  70  71  72  73  75  76  77  80  83  86  87  89  90  91  92
#   93  94  95  96  99 100 101 102 103 104 105 108 110 111 112 113 114 115
#  116 117 118 119 120 121 122 124 126 129 130 131 132 134 135 137 138 139
#  140 143 144 145 147 148 149 150 152 153 154 155 157 158 159 160 162 163
#  164 167 168 169 170 171 173 174 175 176 177 178 179 180 181 182 185 188
#  189 191 196 197 199 200 201 202 203 205 206 210 212 213 214 217 219 221
#  222 223 225 227 228 229 231 232 234 235 236 238 239 240 242 243 244 245
#  246 249 250 251 252 253 254 260 262 263 264 265 266 270 273 276 277 278
#  280 281 282 284 285 287 292 293 294 295 296 297 302 304 308 312 313 314
#  317 320 321 324 326 331 332 333 335 336 339 342 343 344 349 350 351 352
#  353 354 355 357 360 361 362 363 364 365 371 372 373 374 377 378 379 382
# ...

# %%
jahaj.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone  yuhi
# 0    man        True  NaN  Southampton    no  False  10.0
# 1  woman       False    C    Cherbourg   yes  False   NaN
# 2  woman       False  NaN  Southampton   yes   True   NaN
# 3  woman       False    C  Southampton   yes  False   NaN
# 4    man        True  NaN  Southampton    no   True  10.0

# %%
list=(23492, 30715, 12058, 54932, 65897)
print(np.median(np.array(list)))
# Out:
# 30715.0
